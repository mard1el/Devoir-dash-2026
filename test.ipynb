# %%
# Import libraries
from dash import Dash, dash_table
import dash_bootstrap_components as dbc
import pandas as pd
import plotly.express as px
# Out:
# Failed to start the Kernel.
#
# Unable to start Kernel 'devoir-marc-ahanhanzoglele (3.13.12) (Python 3.13.12)' due to a timeout waiting for the ports to get used.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
df = datas/avocado.csv
app = Dash(__name__, external_stylesheets=[dbc.themes.BOOTSTRAP])
data_table = dash_table.DataTable(id="our-data-table", page_size=10)

# %%
df.drop(["Unnamed : 0", "4046", "4225", "4770" ,"Small Bags", "Large Bags", "XLarge Bags"], axis=1, inplace=True )
